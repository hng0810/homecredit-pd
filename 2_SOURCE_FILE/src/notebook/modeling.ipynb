# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)
import utils.utils as ut

# %%
path = r'../../../0_DATA_PULL/features.csv'
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (307511, 283)
